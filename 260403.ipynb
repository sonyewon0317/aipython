# %%
import random
answer=(random.randint(1, 100))

# %%
answer
# Out:
# 65

# %%
user=int(input("추측값을 입력하시오"))
# Out:
# 추측값을 입력하시오60

# %%
count=0
while user != answer:
  if user > answer:
    print("더 작은 값을 입력하시오")
    count+=1
  else:
    print("더 큰 값을 입력하시오")
    count+=1
  user=int(input("추측값을 입력하시오"))
print("총 시도 횟수:", count)
# Out:
# 더 큰 값을 입력하시오
# 추측값을 입력하시오70
# 더 작은 값을 입력하시오
# 추측값을 입력하시오65
# 총 시도 횟수: 2

# %%
num=int(input("약수를 구하려는 숫자를 입력하시오"))
for i in range(1, num + 1):
    if num % i == 0:
      print(i)
# Out:
# 약수를 구하려는 숫자를 입력하시오24
# 1
# 2
# 3
# 4
# 6
# 8
# 12
# 24
