# %%
i=0
while i < 5:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
a = [1, 2, 3]
b = ["apple", "banana"]
c = [1, "hi", 3.14, {10, 20}]
d = []

# %%
a.append(4)

# %%
sorted(a)
# Out:
# [1, 2, 3, 4]

# %%
len(a)
# Out:
# 4

# %%
sum(a)
# Out:
# 10

# %%
list(reversed(a))
# Out:
# [4, 3, 2, 1]

# %%
fruits = ["apple", "banana", "cheerry"]

# %%
fruits.extend([
    "orange", "grape", "mango", "peach", "pear",
    "pineapple", "strawberry", "watermelon", "kiwi", "lemon"
])

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'cheerry',
#  'orange',
#  'grape',
#  'mango',
#  'peach',
#  'pear',
#  'pineapple',
#  'strawberry',
#  'watermelon',
#  'kiwi',
#  'lemon']

# %%
len(fruits)
# Out:
# 13

# %%
for a in fruits:
  print(a)
# Out:
# apple
# banana
# cheerry
# orange
# grape
# mango
# peach
# pear
# pineapple
# strawberry
# watermelon
# kiwi
# lemon

# %%
upper_fruits = []
for fruit in fruits:
    if fruit.isupper():
        upper_fruits.append(fruit)
print(upper_fruits)
# Out:
# []

# %%
upper_fruits = []
for fruit in fruits:
    upper_fruits.append(fruit.upper())
print(upper_fruits)
# Out:
# ['APPLE', 'BANANA', 'CHEERRY', 'ORANGE', 'GRAPE', 'MANGO', 'PEACH', 'PEAR', 'PINEAPPLE', 'STRAWBERRY', 'WATERMELON', 'KIWI', 'LEMON']

# %%
for i, fruit in enumerate(fruits,start=1):
    print(f"{i}, {fruit}")
# Out:
# 1, apple
# 2, banana
# 3, cheerry
# 4, orange
# 5, grape
# 6, mango
# 7, peach
# 8, pear
# 9, pineapple
# 10, strawberry
# 11, watermelon
# 12, kiwi
# 13, lemon

# %%
for i, fruit in enumerate(fruits):
    print(f"{i+1}, {fruit}")
# Out:
# 1, apple
# 2, banana
# 3, cheerry
# 4, orange
# 5, grape
# 6, mango
# 7, peach
# 8, pear
# 9, pineapple
# 10, strawberry
# 11, watermelon
# 12, kiwi
# 13, lemon

# %%
joseon_kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]
for i, king_name in enumerate(joseon_kings):
    print(f"{i+1}대왕 {king_name}")
n = int(input("조선 몇 대 왕을 알고 싶나요? (1~27): "))
print(f"조선 {n}대왕은 {joseon_kings[n-1]}입니다.")
# Out:
# 1대왕 태조
# 2대왕 정종
# 3대왕 태종
# 4대왕 세종
# 5대왕 문종
# 6대왕 단종
# 7대왕 세조
# 8대왕 예종
# 9대왕 성종
# 10대왕 연산군
# 11대왕 중종
# 12대왕 인종
# 13대왕 명종
# 14대왕 선조
# 15대왕 광해군
# 16대왕 인조
# 17대왕 효종
# 18대왕 현종
# 19대왕 숙종
# 20대왕 경종
# 21대왕 영조
# 22대왕 정조
# 23대왕 순조
# 24대왕 헌종
# 25대왕 철종
# 26대왕 고종
# 27대왕 순종
# 조선 몇 대 왕을 알고 싶나요? (1~27): 12
# 조선 12대왕은 인종입니다.

# %%
joseon_kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]
name = input("조선의 왕 이름을 입력하세요: ")
if name in joseon_kings:
    n = joseon_kings.index(name) + 1
    print(f"{name}은(는) 조선 {n}대왕입니다.")
else:
    print(f"{name}은(는) 목록에 없습니다.")
# Out:
# 조선의 왕 이름을 입력하세요: 순조
# 순조은(는) 조선 23대왕입니다.

# %%
joseon_kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]

# %%
for i in range(len(joseon_kings)-1,-1,-1):
    print(joseon_kings[i])
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조

# %%
for i in list(reversed(joseon_kings)):
    print(i)
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조
